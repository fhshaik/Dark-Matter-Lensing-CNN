# %%
pip install taichi

# %%
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Change working directory to Google Drive
os.chdir('/content/drive/My Drive/My Folder')

# Write a sample file to Google Drive
with open('sample.txt', 'w') as f:
  f.write('Hallo, World!')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: run raytracer.py

# !python raytracer.py "SimLensing Dataset/lensing" "2.png"
# Out:
# [Taichi] version 1.7.1, llvm 15.0.4, commit 0f143b2f, linux, python 3.10.12
# [Taichi] Starting on arch=cuda
# /content/drive/My Drive/My Folder/raytracer.py:96: SyntaxWarning: Calling non-taichi function "np.random.normal". Scope inside the function is not processed by the Taichi AST transformer. The function may not work as expected. Proceed with caution! Maybe you can consider turning it into a @ti.func?
#   focal_length = ti.abs(np.random.normal(1,1))
# /content/drive/My Drive/My Folder/raytracer.py:27: SyntaxWarning: Calling non-taichi function "np.random.uniform". Scope inside the function is not processed by the Taichi AST transformer. The function may not work as expected. Proceed with caution! Maybe you can consider turning it into a @ti.func?
#   theta = np.random.uniform(0, np.pi)
# ...

# %%
import os

folder = "SimLensing Dataset/lensing"
  # Replace with your desired output folder


# Number of times to run the command
num_runs = 1000

for i in range(1, num_runs + 1):
    file = f"{i}.png"
    command = f"python raytracer.py \"{folder}\" \"{file}\""
    print(command)
    os.system(command)
# Out:
# python raytracer.py "SimLensing Dataset/lensing" "1.png"
# python raytracer.py "SimLensing Dataset/lensing" "2.png"
# python raytracer.py "SimLensing Dataset/lensing" "3.png"
# python raytracer.py "SimLensing Dataset/lensing" "4.png"
# python raytracer.py "SimLensing Dataset/lensing" "5.png"
# python raytracer.py "SimLensing Dataset/lensing" "6.png"
# python raytracer.py "SimLensing Dataset/lensing" "7.png"
# python raytracer.py "SimLensing Dataset/lensing" "8.png"
# python raytracer.py "SimLensing Dataset/lensing" "9.png"
# python raytracer.py "SimLensing Dataset/lensing" "10.png"
# python raytracer.py "SimLensing Dataset/lensing" "11.png"
# python raytracer.py "SimLensing Dataset/lensing" "12.png"
# python raytracer.py "SimLensing Dataset/lensing" "13.png"
# python raytracer.py "SimLensing Dataset/lensing" "14.png"
# python raytracer.py "SimLensing Dataset/lensing" "15.png"
# python raytracer.py "SimLensing Dataset/lensing" "16.png"
# ...

# %%
import os

folder = "SimLensing Dataset/no_lensing"
  # Replace with your desired output folder


# Number of times to run the command
num_runs = 1000

for i in range(1, num_runs + 1):
    file = f"{i}.png"
    command = f"python raytracer2.py \"{folder}\" \"{file}\""
    print(command)
    os.system(command)
# Out:
# python raytracer2.py "SimLensing Dataset/no_lensing" "1.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "2.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "3.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "4.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "5.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "6.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "7.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "8.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "9.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "10.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "11.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "12.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "13.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "14.png"
# python raytracer2.py "SimLensing Dataset/no_lensing" "15.png"
# ...
